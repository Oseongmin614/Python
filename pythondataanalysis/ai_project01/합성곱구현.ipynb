# %%
# 라이브러리 불러오기
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# 이미지 데이터 정의 (1x9x9 이미지, 오른쪽 가장자리에 값 0.4)
image = torch.tensor([[[[0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4],
                        [0, 0, 0, 0, 0, 0, 0, 0, 0.4],
                        [0, 0, 0, 0, 0, 0, 0, 0, 0.4],
                        [0, 0, 0, 0, 0, 0, 0, 0, 0.4],
                        [0, 0, 0, 0, 0, 0, 0, 0, 0.4],
                        [0, 0, 0, 0, 0, 0, 0, 0, 0.4],
                        [0, 0, 0, 0, 0, 0, 0, 0, 0.4],
                        [0, 0, 0, 0, 0, 0, 0, 0, 0.4],
                        [0, 0, 0, 0, 0, 0, 0, 0, 0.4]]]], dtype=torch.float32)

# 이미지 시각화
plt.imshow(image.data.squeeze(), cmap='gray_r', vmin=0, vmax=1)

# 라벨 정의
label = torch.tensor([[7.]], dtype=torch.float32)

# 모델 정의 (합성곱 3x3 → ReLU → Flatten → Linear)
model = nn.Sequential(
    nn.Conv2d(1, 1, kernel_size=3, bias=False),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(49, 1)
)

# 가중치 초기화 (정규분포)
with torch.no_grad():
    model[0].weight.normal_(mean=0.0, std=0.01)

# 손실 함수 및 옵티마이저 설정
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.0005)

# %%
for epoch in range(1000):
    optimizer.zero_grad()

    relu_result = model[1](model[0](image))
    output = model(image)
    loss = criterion(output, label)
    loss.backward()
    optimizer.step()

    if (epoch+1) % 50 == 0 or (epoch == 0):
        print(f"\n==> Epoch [{epoch+1}]")
        print(f"# 필터맵:\n{relu_result.data.squeeze()}")
        print(f"# 최종 예측값: {output.item():.4f}")
        print(f"# 손실값: {loss.item():.4f}")
        print(f"# 수정된 필터값:\n{model[0].weight.data.squeeze()}")

        plt.figure(figsize=(3,3))
        plt.imshow(relu_result.data.squeeze(), cmap='gray_r', vmin=0, vmax=1)
        plt.title(f'Epoch {epoch+1} - ReLU Result')
        plt.axis('off')
        plt.show()
# Out:
# ==> Epoch [1]
# # 필터맵:
# tensor([[0.0072, 0.0072, 0.0072, 0.0072, 0.0072, 0.0072, 0.0063],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0026],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0026],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0026],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0026],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0026],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0026]])
# # 최종 예측값: -0.1140
# # 손실값: 50.6092
# # 수정된 필터값:
# tensor([[ 0.0140, -0.0050,  0.0096],
#         [-0.0105,  0.0029,  0.0059],
#         [ 0.0083,  0.0006, -0.0066]])
# ==> Epoch [50]
# # 필터맵:
# tensor([[0.0216, 0.0216, 0.0216, 0.0216, 0.0216, 0.0216, 0.0490],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0494],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0494],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0494],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0494],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0494],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0494]])
# # 최종 예측값: 0.2422
# # 손실값: 45.6676
# # 수정된 필터값:
# tensor([[ 0.0090, -0.0101,  0.0559],
#         [-0.0105,  0.0029,  0.0414],
#         [ 0.0083,  0.0006,  0.0289]])
# ==> Epoch [100]
# # 필터맵:
# tensor([[0.0503, 0.0503, 0.0503, 0.0503, 0.0503, 0.0503, 0.1173],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1153],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1153],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1153],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1153],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1153],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1153]])
# # 최종 예측값: 0.6176
# # 손실값: 40.7347
# # 수정된 필터값:
# tensor([[ 0.0123, -0.0068,  0.1222],
#         [-0.0105,  0.0029,  0.0913],
#         [ 0.0083,  0.0006,  0.0787]])
# ==> Epoch [150]
# # 필터맵:
# tensor([[0.1083, 0.1083, 0.1083, 0.1083, 0.1083, 0.1083, 0.2379],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2202],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2202],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2202],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2202],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2202],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2202]])
# # 최종 예측값: 1.0781
# # 손실값: 35.0683
# # 수정된 필터값:
# tensor([[ 0.0324,  0.0133,  0.2289],
#         [-0.0105,  0.0029,  0.1703],
#         [ 0.0083,  0.0006,  0.1578]])
# ==> Epoch [200]
# # 필터맵:
# tensor([[0.2134, 0.2134, 0.2134, 0.2134, 0.2134, 0.2134, 0.4409],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3854],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3854],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3854],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3854],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3854],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3854]])
# # 최종 예측값: 1.8119
# # 손실값: 26.9167
# # 수정된 필터값:
# tensor([[ 0.0802,  0.0611,  0.3989],
#         [-0.0105,  0.0029,  0.2936],
#         [ 0.0083,  0.0006,  0.2811]])
# ==> Epoch [250]
# # 필터맵:
# tensor([[0.3690, 0.3690, 0.3690, 0.3690, 0.3690, 0.3690, 0.7279],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6096],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6096],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6096],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6096],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6096],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6096]])
# # 최종 예측값: 3.1012
# # 손실값: 15.2004
# # 수정된 필터값:
# tensor([[ 1.5917e-01,  1.4012e-01,  6.3168e-01],
#         [-1.0497e-02,  2.9457e-03,  4.5831e-01],
#         [ 8.3180e-03,  5.5246e-04,  4.4580e-01]])
# ==> Epoch [300]
# # 필터맵:
# tensor([[0.5288, 0.5288, 0.5288, 0.5288, 0.5288, 0.5288, 1.0148],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8282],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8282],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8282],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8282],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8282],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8282]])
# # 최종 예측값: 4.7977
# # 손실값: 4.8502
# # 수정된 필터값:
# tensor([[ 2.4422e-01,  2.2516e-01,  8.5939e-01],
#         [-1.0497e-02,  2.9457e-03,  6.1639e-01],
#         [ 8.3180e-03,  5.5246e-04,  6.0387e-01]])
# ==> Epoch [350]
# # 필터맵:
# tensor([[0.6304, 0.6304, 0.6304, 0.6304, 0.6304, 0.6304, 1.1947],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9636],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9636],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9636],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9636],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9636],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9636]])
# # 최종 예측값: 6.0866
# # 손실값: 0.8343
# # 수정된 필터값:
# tensor([[ 2.9918e-01,  2.8012e-01,  1.0001e+00],
#         [-1.0497e-02,  2.9457e-03,  7.1290e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.0038e-01]])
# ==> Epoch [400]
# # 필터맵:
# tensor([[0.6738, 0.6738, 0.6738, 0.6738, 0.6738, 0.6738, 1.2710],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0207],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0207],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0207],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0207],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0207],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0207]])
# # 최종 예측값: 6.6868
# # 손실값: 0.0981
# # 수정된 필터값:
# tensor([[ 3.2272e-01,  3.0366e-01,  1.0592e+00],
#         [-1.0497e-02,  2.9457e-03,  7.5326e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.4075e-01]])
# ==> Epoch [450]
# # 필터맵:
# tensor([[0.6887, 0.6887, 0.6887, 0.6887, 0.6887, 0.6887, 1.2972],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0403],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0403],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0403],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0403],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0403],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0403]])
# # 최종 예측값: 6.9007
# # 손실값: 0.0099
# # 수정된 필터값:
# tensor([[ 3.3085e-01,  3.1179e-01,  1.0795e+00],
#         [-1.0497e-02,  2.9457e-03,  7.6707e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.5456e-01]])
# ==> Epoch [500]
# # 필터맵:
# tensor([[0.6934, 0.6934, 0.6934, 0.6934, 0.6934, 0.6934, 1.3056],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0465],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0465],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0465],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0465],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0465],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0465]])
# # 최종 예측값: 6.9694
# # 손실값: 0.0009
# # 수정된 필터값:
# tensor([[ 3.3342e-01,  3.1437e-01,  1.0859e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7144e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.5893e-01]])
# ==> Epoch [550]
# # 필터맵:
# tensor([[0.6949, 0.6949, 0.6949, 0.6949, 0.6949, 0.6949, 1.3081],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0484],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0484],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0484],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0484],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0484],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0484]])
# # 최종 예측값: 6.9906
# # 손실값: 0.0001
# # 수정된 필터값:
# tensor([[ 3.3422e-01,  3.1516e-01,  1.0879e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7279e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6028e-01]])
# ==> Epoch [600]
# # 필터맵:
# tensor([[0.6954, 0.6954, 0.6954, 0.6954, 0.6954, 0.6954, 1.3089],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0490],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0490],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0490],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0490],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0490],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0490]])
# # 최종 예측값: 6.9971
# # 손실값: 0.0000
# # 수정된 필터값:
# tensor([[ 3.3446e-01,  3.1540e-01,  1.0885e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7321e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6069e-01]])
# ==> Epoch [650]
# # 필터맵:
# tensor([[0.6955, 0.6955, 0.6955, 0.6955, 0.6955, 0.6955, 1.3091],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0491],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0491],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0491],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0491],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0491],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0491]])
# # 최종 예측값: 6.9991
# # 손실값: 0.0000
# # 수정된 필터값:
# tensor([[ 3.3454e-01,  3.1548e-01,  1.0887e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7333e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6082e-01]])
# ==> Epoch [700]
# # 필터맵:
# tensor([[0.6955, 0.6955, 0.6955, 0.6955, 0.6955, 0.6955, 1.3092],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492]])
# # 최종 예측값: 6.9997
# # 손실값: 0.0000
# # 수정된 필터값:
# tensor([[ 3.3456e-01,  3.1550e-01,  1.0888e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7337e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6085e-01]])
# ==> Epoch [750]
# # 필터맵:
# tensor([[0.6955, 0.6955, 0.6955, 0.6955, 0.6955, 0.6955, 1.3092],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492]])
# # 최종 예측값: 6.9999
# # 손실값: 0.0000
# # 수정된 필터값:
# tensor([[ 3.3457e-01,  3.1551e-01,  1.0888e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7338e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6087e-01]])
# ==> Epoch [800]
# # 필터맵:
# tensor([[0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 1.3093],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492]])
# # 최종 예측값: 7.0000
# # 손실값: 0.0000
# # 수정된 필터값:
# tensor([[ 3.3457e-01,  3.1551e-01,  1.0888e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7338e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6087e-01]])
# ==> Epoch [850]
# # 필터맵:
# tensor([[0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 1.3093],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492]])
# # 최종 예측값: 7.0000
# # 손실값: 0.0000
# # 수정된 필터값:
# tensor([[ 3.3457e-01,  3.1551e-01,  1.0888e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7339e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6087e-01]])
# ==> Epoch [900]
# # 필터맵:
# tensor([[0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 1.3093],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492]])
# # 최종 예측값: 7.0000
# # 손실값: 0.0000
# # 수정된 필터값:
# tensor([[ 3.3457e-01,  3.1551e-01,  1.0888e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7339e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6087e-01]])
# ==> Epoch [950]
# # 필터맵:
# tensor([[0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 1.3093],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492]])
# # 최종 예측값: 7.0000
# # 손실값: 0.0000
# # 수정된 필터값:
# tensor([[ 3.3457e-01,  3.1551e-01,  1.0888e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7339e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6087e-01]])
# ==> Epoch [1000]
# # 필터맵:
# tensor([[0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 0.6956, 1.3093],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0492]])
# # 최종 예측값: 7.0000
# # 손실값: 0.0000
# # 수정된 필터값:
# tensor([[ 3.3457e-01,  3.1551e-01,  1.0888e+00],
#         [-1.0497e-02,  2.9457e-03,  7.7339e-01],
#         [ 8.3180e-03,  5.5246e-04,  7.6087e-01]])
